# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume uer input
test_input1= np.array([2,'male',31.0,0,0,10.5,'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input1)
# Out:
# C:\Users\souma\anaconda5\Lib\anaconda6\envs\py311\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# C:\Users\souma\anaconda5\Lib\anaconda6\envs\py311\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
